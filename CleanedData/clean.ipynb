# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import warnings
warnings.filterwarnings('ignore')

# %%
paths = {}
for root, dirs, files in os.walk('.\RawData'):
    if root == '.\RawData': continue
    path_list = []
    for file in files: path_list.append(os.path.join(root, file))
    paths[os.path.split(root)[1]] = path_list
for key in paths.keys():
    print(f"{len(paths[key])} csv files in {key}")
# Out:
# 1 csv files in Raw Age Range Data
# 1 csv files in Raw Covid Data
# 1 csv files in Raw Income Data
# 1 csv files in Raw Internet Data
# 51 csv files in Raw Police Data
# 1 csv files in Raw Political Affiliation Data
# 2 csv files in Raw Population Data
# 1 csv files in Raw Race Breakdown
# 1 csv files in Raw Violent Crime Data

# %% [markdown]
# ## Raw Violent Crime

# %%
code, name = [], []
state_fip = {}
with open('fip-look-up.txt', 'r') as file:
    file = file.read().split('\n')
    for line in file:
        line = [word for word in line.split(' ') if word != '']
        code.append(int(line[0]))
        if line[-1].upper() in ["COUNTY", "PARISH", "BOROUGH"]: name.append(' '.join(line[1:-1]).upper())
        else: name.append(' '.join(line[1:]).upper())
        if int(line[0]) % 1000 == 0:
            state_fip[' '.join(line[1:]).upper()] = int(int(line[0]) / 1000)
lookup = pd.DataFrame({"code": code, "name": name})
lookup
# Out:
#        code        name
# 0      1000     ALABAMA
# 1      1001     AUTAUGA
# 2      1003     BALDWIN
# 3      1005     BARBOUR
# 4      1007        BIBB
# ...     ...         ...
# 3190  56037  SWEETWATER
# 3191  56039       TETON
# 3192  56041       UINTA
# 3193  56043    WASHAKIE
# 3194  56045      WESTON
#
# [3195 rows x 2 columns]

# %%
def look_up_fip(state, county):
    try: 
        fip_ = state_fip[state.upper()] * 1000
        county_fip = lookup[(lookup['code'] >= fip_) & (lookup['code'] <= fip_ + 1000) & (lookup['name'] == county.upper())]['code']
        county_fip = county_fip.iloc[0]
    except (IndexError, KeyError): county_fip = -1
    return county_fip

look_up_fip('Alaska', 'Yakutat')
# Out:
# 2282

# %%
df_all = pd.DataFrame()
violent_df = pd.read_csv(paths['Raw Violent Crime Data'][0])
violent_df.columns = ['County',	'Violent crime', 'Murder and nonnegligent manslaughter','Rape1', 'Rape2', 'Robbery', 'Aggravated assault', 'Property crime', 'Burglary',	'Larceny-theft', 'Motor vehicle theft', 'Arson3', 'State']
nul = violent_df['State'].isna()
exceptions = ["NEW", "NORTH", "SOUTH", "WEST"]
for i in range(len(violent_df)):
    if nul[i] == True: violent_df.loc[i, 'State'] = violent_df.loc[i-1, 'State']
    tmp = violent_df.loc[i, 'State'].split(' ')[0]
    if tmp in exceptions: violent_df.loc[i, 'State'] = " ".join(violent_df.loc[i, 'State'].split(' ')[0:2])
    else: violent_df.loc[i, 'State'] = tmp
df_all = pd.concat([df_all, violent_df], axis = 1)
df_all.loc[df_all.County == 'Baltimore County', 'County'] = 'Baltimore'
violent_df.head(3)
# Out:
#     County Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 0  Autauga            73                                     1   12.0    NaN
# 1  Baldwin           127                                     1    5.0    NaN
# 2     Bibb             0                                     0    0.0    NaN
#
#   Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 0       8                 52            429      146           233
# 1      23                 98            613      229           342
# 2       0                  0             37       20            14
#
#   Motor vehicle theft  Arson3    State
# 0                  50     NaN  ALABAMA
# 1                  42     NaN  ALABAMA
# 2                   3     NaN  ALABAMA

# %%
violent_df['State'].unique()
# Out:
# array(['ALABAMA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO',
#        'DELAWARE', 'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS',
#        'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE',
#        'MARYLAND', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI',
#        'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY',
#        'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO',
#        'OKLAHOMA', 'OREGON', 'PENNSYLVANIA', 'SOUTH CAROLINA',
#        'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH', 'VERMONT',
#        'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN', 'WYOMING'],
#       dtype=object)

# %%
# Now edit out government agencies and unrecognizable counties
df_all = df_all.set_index(['State', 'County'])
remove = [('CALIFORNIA', 'Tulare4'),
('COLORADO', 'Eagle5'),
('DELAWARE', 'New Castle County Police Department'),
('GEORGIA', 'Clayton County Police Department'),
('GEORGIA', 'Cobb County Police Department'),
('GEORGIA', 'DeKalb County Police Department'),
('GEORGIA', 'Dougherty County Police Department'),
('GEORGIA', 'Floyd County Police Department'),
('GEORGIA', 'Fulton County Police Department'),
('GEORGIA', 'Glynn County Police Department'),
('GEORGIA', 'Gwinnett County Police Department'),
('GEORGIA', 'Henry County Police Department'),
('GEORGIA', 'Polk County Police Department'),
('HAWAII', 'Maui Police Department'),
('HAWAII', 'Hawaii Police Department'),
('HAWAII', 'Kauai Police Department'),
('KANSAS', 'Riley County Police Department'),
('KANSAS', 'Cherokee6'),
('KANSAS', 'Ford6'),
('KANSAS', 'Labette6'),
('KANSAS', 'Pawnee6'),
('KENTUCKY', 'Campbell County Police Department'),
('KENTUCKY', 'Kenton County Police Department'),
('KENTUCKY', 'Oldham County Police Department'),
('KENTUCKY', 'Muhlenberg County Police Department'),
('LOUISIANA', 'Iberia5'),
('LOUISIANA', 'La Salle'),
('MAINE', 'Androscoggin7'),
('MAINE', 'Cumberland7'),
('MAINE', 'Penobscot7'),
('MAINE', 'Sagadahoc7'),
('MAINE', 'York7'),
('MAINE', 'Aroostook7'),
('MAINE', 'Hancock7'),
('MAINE', 'Knox7'),
('MAINE', 'Lincoln7'),
('MAINE', 'Oxford7'),
('MAINE', 'Piscataquis7'),
('MAINE', 'Waldo7'),
('MAINE', 'Washington7'),
('MARYLAND', 'Anne Arundel County Police Department'),
('MARYLAND', 'Baltimore County Police Department'),
('MARYLAND', 'Howard County Police Department'),
('MARYLAND', 'Montgomery County Police Department'),
('MARYLAND', "Prince George's "),
('MINNESOTA', 'Carver8'),
('MISSISSIPPI', 'Hinds8 '),
('MISSOURI', 'Newton9'),
('MISSOURI', 'St. Charles County Police Department'),
('MISSOURI', 'St. Louis County Police Department'),
('MISSOURI', 'Camden5'),
('NEW JERSEY', 'Camden County Police Department'),
('NEW YORK', 'Suffolk County Police Department'),
('NEW YORK', 'Westchester Public Safety'),
('NEW YORK', 'Fulton7'),
('NORTH CAROLINA', 'Halifax5'),
('NORTH CAROLINA', 'Richmond5'),
('NORTH CAROLINA', 'Sampson5'),
('NORTH CAROLINA', 'Scotland5'),
('SOUTH CAROLINA', 'Horry County Police Department'),
('SOUTH CAROLINA', 'Marion9'),
('TEXAS', 'Bosque9'),
('TEXAS', 'Lavaca9'),
('TEXAS', 'Trinity9'),
('UTAH', 'Salt Lake County Unified Police Department'),
('VIRGINIA', 'Albemarle County Police Department'),
('VIRGINIA', 'Arlington County Police Department'),
('VIRGINIA', 'Chesterfield County Police Department'),
('VIRGINIA', 'Fairfax County Police Department'),
('VIRGINIA', 'Henrico County Police Department'),
('VIRGINIA', 'James City County Police Department'),
('VIRGINIA', 'Prince George County Police Department'),
('VIRGINIA', 'Prince William County Police Department'),
('VIRGINIA', 'Roanoke County Police Department'),
('WASHINGTON', 'Spokane8'),
('WISCONSIN', 'Brown8'),
('WISCONSIN', 'Waushara8')
]
df_all.drop([index for index in remove], axis = 0, inplace = True)
df_all
# Out:
#                    Violent crime  Murder and nonnegligent manslaughter  Rape1  \
# State   County
# ALABAMA Autauga               73                                     1   12.0
#         Baldwin              127                                     1    5.0
#         Bibb                   0                                     0    0.0
#         Blount               394                                     1   17.0
#         Calhoun               23                                     0    7.0
# ...                          ...                                   ...    ...
# WYOMING Sublette               3                                     0    0.0
#         Sweetwater            25                                     0    7.0
#         Uinta                  4                                     0    0.0
#         Washakie               0                                     0    0.0
#         Weston                 1                                     0    0.0
#
#                     Rape2 Robbery Aggravated assault Property crime Burglary  \
# State   County
# ALABAMA Autauga       NaN       8                 52            429      146
#         Baldwin       NaN      23                 98            613      229
#         Bibb          NaN       0                  0             37       20
#         Blount        NaN       9                367            867      261
#         Calhoun       NaN       5                 11            319      137
# ...                   ...     ...                ...            ...      ...
# WYOMING Sublette      NaN       1                  2             79        5
#         Sweetwater    NaN       0                 18            124       33
#         Uinta         NaN       0                  4             60        5
#         Washakie      NaN       0                  0             14        4
#         Weston        NaN       0                  1              3        0
#
#                    Larceny-theft Motor vehicle theft  Arson3
# State   County
# ALABAMA Autauga              233                  50     NaN
#         Baldwin              342                  42     NaN
#         Bibb                  14                   3     NaN
#         Blount               501                 105     NaN
#         Calhoun              181                   1     NaN
# ...                          ...                 ...     ...
# WYOMING Sublette              69                   5     0.0
#         Sweetwater            69                  22     5.0
#         Uinta                 50                   5     0.0
#         Washakie               7                   3     0.0
#         Weston                 3                   0     0.0
#
# [2535 rows x 11 columns]

# %%
# Use fip as index
def convert(df):
    new_idxs = [look_up_fip(state, county) for (state, county) in df.index.values]
    df.index = new_idxs 
    df.drop([-1], inplace = True, axis = 0)
    df[df.index == -1]

convert(df_all)

# %% [markdown]
# ## Raw Age Range Data

# %%
age_df = pd.read_csv(paths['Raw Age Range Data'][0])
age_df.head(5)
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  POPESTIMATE  \
# 0      50      1       1  Alabama  Autauga County     1        58802
# 1      50      1       1  Alabama  Autauga County     2        58902
# 2      50      1       1  Alabama  Autauga County     3        59210
# 3      50      1       1  Alabama  Autauga County     4        59759
# 4      50      1       3  Alabama  Baldwin County     1       231761
#
#    POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# 0        28761       30041        3443  ...         1055         1165
# 1        28819       30083        3457  ...         1064         1170
# 2        28851       30359        3416  ...         1074         1190
# 3        29105       30654        3460  ...         1152         1225
# 4       113388      118373       12046  ...         4861         5601
#
#    AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  AGE85PLUS_FEM  \
# 0           501          664            955             345            610
# 1           501          669            958             350            608
# 2           492          698            972             362            610
# 3           495          730           1019             385            634
# 4          2542         3059           4610            1812           2798
#
#    MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 0            39.2             37.9            40.3
# 1            39.1             37.9            40.3
# 2            39.2             38.0            40.3
# 3            39.2             38.0            40.4
# 4            43.7             42.5            44.9
#
# [5 rows x 96 columns]

# %%
age_df.rename(columns = {'STNAME': 'State', "CTYNAME": 'County'}, inplace = True)
end_words = ['County', 'Borough', 'Parish']
age_df['County'] = age_df['County'].apply(lambda x: ' '.join(x.split(' ')[0:-1]) if x.split(' ')[-1] in end_words else x)
age_df['State'] = age_df['State'].apply(lambda x: x.upper())
age_df.set_index(['State', "County"], inplace=True)
age_df.sample(10)
# Out:
#                           SUMLEV  STATE  COUNTY  YEAR  POPESTIMATE  \
# State      County
# LOUISIANA  Lafourche          50     22      57     1        97552
# MISSOURI   Clinton            50     29      49     2        21210
# INDIANA    Morgan             50     18     109     4        72236
# VIRGINIA   Loudoun            50     51     107     3       428435
# ILLINOIS   Moultrie           50     17     139     3        14509
# GEORGIA    Polk               50     13     233     1        42854
# CALIFORNIA San Francisco      50      6      75     3       811253
# TENNESSEE  Houston            50     47      83     3         8282
# MISSOURI   Madison            50     29     123     3        12671
# GEORGIA    Cook               50     13      75     4        17404
#
#                           POPEST_MALE  POPEST_FEM  UNDER5_TOT  UNDER5_MALE  \
# State      County
# LOUISIANA  Lafourche            48296       49256        5804         2913
# MISSOURI   Clinton              10712       10498        1205          593
# INDIANA    Morgan               36121       36115        3729         1894
# VIRGINIA   Loudoun             215027      213408       26999        13755
# ILLINOIS   Moultrie              7174        7335         836          439
# GEORGIA    Polk                 21178       21676        2817         1417
# CALIFORNIA San Francisco       417449      393804       34332        17464
# TENNESSEE  Houston               4086        4196         424          212
# MISSOURI   Madison               6363        6308         680          325
# GEORGIA    Cook                  8332        9072        1041          504
#
#                           UNDER5_FEM  ...  AGE7579_FEM  AGE8084_TOT  \
# State      County                     ...
# LOUISIANA  Lafourche            2891  ...         1551         1872
# MISSOURI   Clinton               612  ...          352          462
# INDIANA    Morgan               1835  ...         1332         1503
# VIRGINIA   Loudoun             13244  ...         4549         5076
# ILLINOIS   Moultrie              397  ...          233          312
# GEORGIA    Polk                 1400  ...          709          746
# CALIFORNIA San Francisco       16868  ...        12803        17192
# TENNESSEE  Houston               212  ...          158          212
# MISSOURI   Madison               355  ...          240          283
# GEORGIA    Cook                  537  ...          295          355
#
#                           AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  \
# State      County
# LOUISIANA  Lafourche               804         1068           1772
# MISSOURI   Clinton                 220          242            513
# INDIANA    Morgan                  655          848           1184
# VIRGINIA   Loudoun                2166         2910           5042
# ILLINOIS   Moultrie                124          188            405
# GEORGIA    Polk                    325          421            607
# CALIFORNIA San Francisco          7250         9942          22169
# TENNESSEE  Houston                  94          118            155
# MISSOURI   Madison                 120          163            294
# GEORGIA    Cook                    136          219            287
#
#                           AGE85PLUS_MALE  AGE85PLUS_FEM  MEDIAN_AGE_TOT  \
# State      County
# LOUISIANA  Lafourche                 591           1181            38.4
# MISSOURI   Clinton                   210            303            41.5
# INDIANA    Morgan                    432            752            42.3
# VIRGINIA   Loudoun                  1867           3175            37.6
# ILLINOIS   Moultrie                  124            281            39.6
# GEORGIA    Polk                      183            424            37.1
# CALIFORNIA San Francisco            8108          14061            40.5
# TENNESSEE  Houston                    45            110            43.4
# MISSOURI   Madison                   126            168            42.1
# GEORGIA    Cook                       76            211            38.1
#
#                           MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# State      County
# LOUISIANA  Lafourche                 37.7            39.1
# MISSOURI   Clinton                   41.1            41.9
# INDIANA    Morgan                    41.5            43.2
# VIRGINIA   Loudoun                   37.4            37.8
# ILLINOIS   Moultrie                  38.2            41.0
# GEORGIA    Polk                      36.0            38.2
# CALIFORNIA San Francisco             40.2            40.9
# TENNESSEE  Houston                   42.6            44.2
# MISSOURI   Madison                   40.8            43.2
# GEORGIA    Cook                      37.2            39.1
#
# [10 rows x 94 columns]

# %%
age_df = age_df[age_df['YEAR']==4]
age_df.drop(['STATE', 'COUNTY', 'SUMLEV', 'YEAR'], axis = 1, inplace=True)
print(len([idx for idx in age_df.index if idx in df_all.index]))
print(len(df_all.index))
# Out:
# 0
# 2525

# %%
convert(age_df)

# %%
print("These counties fail to match")
for idx in df_all.index:
    if idx not in age_df.index:
        print(idx)
# Out:
# These counties fail to match
# 17099
# 18091
# 18033
# 35013

# %%
dropidx = [idx for idx in age_df.index if idx not in df_all.index]
age_df.drop(dropidx, axis = 0, inplace = True)
print(len(age_df))
print(len(df_all))
df_all = pd.concat([df_all, age_df], axis = 1)
df_all
# Out:
# 2521
# 2525
#       Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 1001             73                                     1   12.0    NaN
# 1003            127                                     1    5.0    NaN
# 1007              0                                     0    0.0    NaN
# 1009            394                                     1   17.0    NaN
# 1015             23                                     0    7.0    NaN
# ...             ...                                   ...    ...    ...
# 56035             3                                     0    0.0    NaN
# 56037            25                                     0    7.0    NaN
# 56041             4                                     0    0.0    NaN
# 56043             0                                     0    0.0    NaN
# 56045             1                                     0    0.0    NaN
#
#       Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 1001        8                 52            429      146           233
# 1003       23                 98            613      229           342
# 1007        0                  0             37       20            14
# 1009        9                367            867      261           501
# 1015        5                 11            319      137           181
# ...       ...                ...            ...      ...           ...
# 56035       1                  2             79        5            69
# 56037       0                 18            124       33            69
# 56041       0                  4             60        5            50
# 56043       0                  0             14        4             7
# 56045       0                  1              3        0             3
#
#       Motor vehicle theft  ...  AGE7579_FEM  AGE8084_TOT  AGE8084_MALE  \
# 1001                   50  ...       1152.0       1225.0         495.0
# 1003                   42  ...       5709.0       6113.0        2811.0
# 1007                    3  ...        460.0        508.0         229.0
# 1009                  105  ...       1307.0       1328.0         563.0
# 1015                    1  ...       2322.0       2431.0         997.0
# ...                   ...  ...          ...          ...           ...
# 56035                   5  ...        206.0        237.0         119.0
# 56037                  22  ...        503.0        590.0         287.0
# 56041                   5  ...        255.0        316.0         147.0
# 56043                   3  ...        187.0        250.0         125.0
# 56045                   0  ...        127.0        141.0          71.0
#
#        AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  AGE85PLUS_FEM  \
# 1001         730.0         1019.0           385.0          634.0
# 1003        3302.0         4933.0          1967.0         2966.0
# 1007         279.0          418.0           122.0          296.0
# 1009         765.0         1222.0           467.0          755.0
# 1015        1434.0         2101.0           595.0         1506.0
# ...            ...            ...             ...            ...
# 56035        118.0          184.0            99.0           85.0
# 56037        303.0          498.0           174.0          324.0
# 56041        169.0          277.0           104.0          173.0
# 56043        125.0          212.0            73.0          139.0
# 56045         70.0          170.0            58.0          112.0
#
#        MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 1001             39.2             38.0            40.4
# 1003             44.1             42.9            45.3
# 1007             40.9             39.1            43.6
# 1009             41.2             40.4            42.1
# 1015             39.3             37.6            40.9
# ...               ...              ...             ...
# 56035            44.7             44.8            44.7
# 56037            37.7             37.8            37.6
# 56041            38.0             38.1            37.9
# 56043            44.8             43.3            46.6
# 56045            44.5             43.6            46.0
#
# [2525 rows x 101 columns]

# %% [markdown]
# ## COVID

# %%
ref = pd.read_csv('state-ref.csv')
code_to_name = {code:name.upper() for (code, name) in zip(ref['code'].values, ref['state'].values)}
code_to_name['US'] = 'US'
code_to_name['PR'] = 'PR'
code_to_name['HAWAII'] = 'HAWAII'
code_to_name['HI'] = 'HAWAII'

# %%
covid_path = paths['Raw Covid Data'][0]
covid_df = pd.read_csv(covid_path)
covid_df['State'] = covid_df['State'].apply(lambda x: code_to_name[x])
covid_df = covid_df.set_index(['State', 'County'])
cols = ["PerCapitaInc", "PovertyAllAgesPct", "Immigration_Rate_2000_2010", "Ed1LessThanHSPct", "Ed3SomeCollegePct", "Ed5CollegePlusPct", "OwnHomePct", "NumUnemployed2019"]
idxs = [idx for idx in covid_df.index if idx[0] not in ['US', 'PR']]
covid_df = covid_df.loc[idxs, cols]
covid_df.sample(3)
# Out:
#                           PerCapitaInc  PovertyAllAgesPct  \
# State        County
# PENNSYLVANIA Susquehanna       29630.0               12.8
# MISSISSIPPI  Lafayette         26154.0               18.0
# INDIANA      Floyd             32299.0                9.5
#
#                           Immigration_Rate_2000_2010  Ed1LessThanHSPct  \
# State        County
# PENNSYLVANIA Susquehanna                    0.002366         10.812316
# MISSISSIPPI  Lafayette                      1.688640         10.536374
# INDIANA      Floyd                          0.368939          9.722460
#
#                           Ed3SomeCollegePct  Ed5CollegePlusPct  OwnHomePct  \
# State        County
# PENNSYLVANIA Susquehanna          17.242057          17.841467   76.578083
# MISSISSIPPI  Lafayette            19.106692          43.926929   61.199979
# INDIANA      Floyd                21.572661          29.544545   72.438343
#
#                           NumUnemployed2019
# State        County
# PENNSYLVANIA Susquehanna              889.0
# MISSISSIPPI  Lafayette               1280.0
# INDIANA      Floyd                   1321.0

# %%
convert(covid_df)
covid_df.sample(3)
# Out:
#        PerCapitaInc  PovertyAllAgesPct  Immigration_Rate_2000_2010  \
# 54051       24882.0               13.9                    0.097460
# 37131       20538.0               21.4                    0.147452
# 13091       18921.0               26.5                    0.834725
#
#        Ed1LessThanHSPct  Ed3SomeCollegePct  Ed5CollegePlusPct  OwnHomePct  \
# 54051          9.042093          20.989953          18.504244   80.264879
# 37131         20.546943          17.366425          12.808570   69.042652
# 13091         16.760450          19.239014          13.699089   66.168443
#
#        NumUnemployed2019
# 54051              902.0
# 37131              406.0
# 13091              381.0

# %%
vis = {idx : True for idx in covid_df.index}
discard = []
for idx in covid_df.index:
    if vis[idx] == False:
        discard.append(idx)
    vis[idx] = False
discard = np.unique(discard)
covid_df.drop(discard, inplace = True, axis = 0)

# %%
idxs = [idx for idx in covid_df.index if idx in df_all.index]
covid_df = covid_df.loc[idxs, cols]
df_all = pd.concat([df_all, covid_df], axis = 1)
df_all.sample(3)
# Out:
#       Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 37127            70                                     2    NaN   11.0
# 13275            63                                     0    NaN    7.0
# 48257           136                                     1   28.0    NaN
#
#       Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 37127       5                 52            425      183           218
# 13275      12                 44            484      147           289
# 48257      11                 96            551      196           275
#
#       Motor vehicle theft  ...  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM  PerCapitaInc  \
# 37127                  24  ...             40.0            43.3       26980.0
# 13275                  48  ...             38.9            41.8       25542.0
# 48257                  80  ...             33.3            34.4       27411.0
#
#        PovertyAllAgesPct  Immigration_Rate_2000_2010  Ed1LessThanHSPct  \
# 37127               14.2                    1.081007         14.599477
# 13275               20.2                    0.823040         17.383589
# 48257               11.5                    2.218071         13.830805
#
#        Ed3SomeCollegePct  Ed5CollegePlusPct  OwnHomePct  NumUnemployed2019
# 37127          20.750777          20.888435   65.669935             2099.0
# 13275          21.780421          23.071867   63.180037              663.0
# 48257          24.204565          20.712123   76.300717             2112.0
#
# [3 rows x 109 columns]

# %% [markdown]
# ## Income
#
# This data is redundant with COVID data.

# %% [markdown]
# ## Internet

# %%
path = paths['Raw Internet Data'][0]
internet_df = pd.read_excel(path)
internet_df.sample(3)
# Out:
#        Year  Month   FIPS  State  County State_Name     County_Name  \
# 18402  2011      6  41045     41      45     Oregon  Malheur County
# 8019   2012     12  29129     29     129   Missouri   Mercer County
# 35270  2008     12  51595     51     595   Virginia    Emporia city
#
#        Housing_Units  Tier_1  Tier_2  Tier_3  Tier_4
# 18402          11690       3       3       2       1
# 8019            2134       3       3       2       1
# 35270           2552       1       1       1       1

# %%
internet_df = internet_df.loc[(internet_df['Year'] == 2013) & (internet_df['Month'] == 12), :]
end_words = ['County', 'Borough', 'Parish']
internet_df['County_Name'] = internet_df['County_Name'].apply(lambda x: ' '.join(x.split(' ')[0:-1]) if x.split(' ')[-1] in end_words else x)
internet_df.set_index(['State_Name', 'County_Name'], inplace = True)
convert(internet_df)

# %%
idxs = [idx for idx in internet_df.index if idx in df_all.index]
internet_df = internet_df.loc[idxs, :]
df_all = pd.concat([df_all, internet_df], axis = 1)
df_all.sample(3)
# Out:
#       Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 20173            24                                     4    1.0    NaN
# 38011             0                                     0    0.0    NaN
# 39141           120                                     1   31.0    NaN
#
#       Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 20173       1                 18             89       37            31
# 38011       0                  0              7        1             1
# 39141      12                 76          1,316      405           844
#
#       Motor vehicle theft  ...    Year  Month     FIPS  State  County  \
# 20173                  21  ...  2013.0   12.0  20173.0   20.0   173.0
# 38011                   5  ...  2013.0   12.0  38011.0   38.0    11.0
# 39141                  67  ...  2013.0   12.0  39141.0   39.0   141.0
#
#        Housing_Units  Tier_1  Tier_2  Tier_3  Tier_4
# 20173       214093.0     4.0     4.0     3.0     2.0
# 38011         1726.0     4.0     4.0     3.0     3.0
# 39141        32083.0     4.0     4.0     3.0     2.0
#
# [3 rows x 119 columns]

# %% [markdown]
# ## Raw Police Data

# %%
police_by_state = {}
for path in paths['Raw Police Data']:
    state_abbr = os.path.basename(path)[0:2]
    state = code_to_name[state_abbr]
    police_by_state[state] = pd.read_csv(path)

# %%
df_police = pd.DataFrame()
cols = ['male_officer', 'female_officer', "county_name"]
for (state, df_police_) in police_by_state.items():
    county_names = df_police_['county_name'].apply(lambda x: x.split(',')[0]).unique()
    df_police_ = df_police_.loc[:, cols]
    df_police_ = df_police_.groupby('county_name').sum() # by county sum
    df_police_['state'] = [state] * len(df_police_)
    df_police_['county'] = df_police_.index
    df_police_.set_index(['state', 'county'], inplace = True)
    df_police = pd.concat([df_police, df_police_], axis = 0)

# %%
convert(df_police)
df_police
# Out:
#        male_officer  female_officer
# 2060            4.0             0.0
# 2090           46.0             3.0
# 2100            4.0             0.0
# 2122           49.0             2.0
# 2130           22.0             1.0
# ...             ...             ...
# 56037          95.0            34.0
# 56039          27.0             4.0
# 56041          46.0             3.0
# 56043          18.0             1.0
# 56045          13.0             2.0
#
# [2676 rows x 2 columns]

# %%
idxs = [idx for idx in df_police.index if idx in df_all.index]
df_police = df_police.loc[idxs, :]
df_all = pd.concat([df_all, df_police], axis = 1)
df_all.sample(3)
# Out:
#       Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 37101           160                                     3    NaN   16.0
# 20169            25                                     1    4.0    NaN
# 51117            32                                     2   11.0    NaN
#
#       Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 37101      39                102          1,874      776         1,000
# 20169       0                 20            128       39            74
# 51117       4                 15            219       84           122
#
#       Motor vehicle theft  ...     FIPS  State  County  Housing_Units  Tier_1  \
# 37101                  98  ...  37101.0   37.0   101.0        69566.0     4.0
# 20169                  15  ...  20169.0   20.0   169.0        24264.0     3.0
# 51117                  13  ...  51117.0   51.0   117.0        18786.0     2.0
#
#        Tier_2  Tier_3  Tier_4  male_officer  female_officer
# 37101     4.0     4.0     3.0         235.0            30.0
# 20169     3.0     3.0     2.0         100.0            15.0
# 51117     2.0     1.0     1.0          81.0             5.0
#
# [3 rows x 121 columns]

# %% [markdown]
# ## Party Affiliation

# %%
path = paths['Raw Political Affiliation Data'][0]
df_affiliation = pd.read_excel(path)
for i in range(len(df_affiliation)):
    try:
        df_affiliation.loc[i, 'State'] = lookup.loc[(lookup['name']==df_affiliation.loc[i, 'State'].upper()) & (lookup['code'] % 1000 == 0), 'code'].iloc[0]
    except KeyError:
        df_affiliation.drop(i, axis = 0, inplace=True)
df_affiliation.set_index('State', inplace=True)
df_affiliation
# Out:
#        Republican/lean Rep.  No lean  Democrat/lean Dem.  Sample size
# State
# 1000                   0.52     0.13                0.35          511
# 2000                   0.39     0.29                0.32          310
# 4000                   0.40     0.21                0.39          653
# 5000                   0.46     0.16                0.38          311
# 6000                   0.30     0.21                0.49         3697
# 8000                   0.41     0.17                0.42          504
# 9000                   0.32     0.18                0.50          377
# 10000                  0.29     0.17                0.55          301
# 11000                  0.11     0.15                0.73          303
# 12000                  0.37     0.19                0.44         2020
# 13000                  0.41     0.18                0.41          968
# 15000                  0.28     0.20                0.51          312
# 16000                  0.49     0.19                0.32          320
# 17000                  0.33     0.19                0.48         1326
# 18000                  0.42     0.20                0.37          654
# 19000                  0.41     0.19                0.40          330
# 20000                  0.46     0.23                0.31          307
# 21000                  0.44     0.13                0.43          439
# 22000                  0.41     0.16                0.43          465
# 23000                  0.36     0.17                0.47          303
# 24000                  0.31     0.14                0.55          644
# 25000                  0.27     0.17                0.56          704
# 26000                  0.34     0.19                0.47          982
# 27000                  0.39     0.15                0.46          563
# 28000                  0.44     0.14                0.42          309
# 29000                  0.41     0.18                0.42          642
# 30000                  0.49     0.21                0.30          312
# 31000                  0.47     0.17                0.36          312
# 32000                  0.37     0.18                0.46          314
# 33000                  0.35     0.20                0.44          303
# 34000                  0.30     0.19                0.51          886
# 35000                  0.37     0.15                0.48          312
# 36000                  0.28     0.19                0.53         1966
# 37000                  0.41     0.17                0.43         1022
# 38000                  0.50     0.18                0.33          338
# 39000                  0.42     0.18                0.40         1132
# 40000                  0.45     0.15                0.40          391
# 41000                  0.32     0.21                0.47          419
# 42000                  0.39     0.15                0.46         1366
# 44000                  0.30     0.22                0.48          305
# 45000                  0.43     0.18                0.39          495
# 46000                  0.53     0.10                0.37          305
# 47000                  0.48     0.15                0.36          661
# 48000                  0.39     0.21                0.40         2535
# 49000                  0.54     0.16                0.30          315
# 50000                  0.29     0.14                0.57          306
# 51000                  0.43     0.18                0.39          882
# 53000                  0.33     0.23                0.44          714
# 54000                  0.43     0.16                0.41          309
# 55000                  0.42     0.16                0.42          600
# 56000                  0.57     0.18                0.25          316

# %%
df_all = pd.concat([df_all, pd.DataFrame({"Republican":[], "Democrat":[]})])
for i, idx in enumerate(df_all.index):
    state_fip_ = int(idx / 1000) * 1000
    df_all.loc[idx, "Republican"] = df_affiliation.loc[state_fip_, "Republican/lean Rep."]
    df_all.loc[idx, "Democrat"] = df_affiliation.loc[state_fip_, "Democrat/lean Dem."]
df_all.sample(3)
# Out:
#       Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 17091            45                                   5.0    1.0    NaN
# 18177            12                                   1.0    5.0    NaN
# 47063           111                                   0.0    7.0    NaN
#
#       Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 17091       6                 33            366      158           185
# 18177       1                  5            275      104           162
# 47063       5                 99            458      148           251
#
#       Motor vehicle theft  ...  County  Housing_Units  Tier_1  Tier_2  Tier_3  \
# 17091                  23  ...    91.0        45304.0     4.0     4.0     3.0
# 18177                   9  ...   177.0        31276.0     3.0     3.0     3.0
# 47063                  59  ...    63.0        27057.0     2.0     2.0     2.0
#
#        Tier_4  male_officer  female_officer  Republican  Democrat
# 17091     3.0           NaN             NaN        0.33      0.48
# 18177     2.0           0.0             0.0        0.42      0.37
# 47063     2.0         101.0             9.0        0.48      0.36
#
# [3 rows x 123 columns]

# %% [markdown]
# ## Population

# %%
path = paths['Raw Population Data'][0]
population_df = pd.read_csv(path)
population_df.drop(0, axis = 0, inplace=True)
population_df.head(3)
# Out:
#                      Region    2020_     2020     2021     2022
# 1  .Autauga County, Alabama   58,802   58,902   59,210   59,759
# 2  .Baldwin County, Alabama  231,761  233,219  239,361  246,435
# 3  .Barbour County, Alabama   25,224   24,960   24,539   24,706

# %%
population_df['County'] = population_df['Region'].apply(lambda x: x.split(',')[0][1:])
population_df['State'] = population_df['Region'].apply(lambda x: x.split(',')[1][1:])
end_words = ['County', 'Borough', 'Parish']
population_df['County'] = population_df['County'].apply(lambda x: ' '.join(x.split(' ')[0:-1]) if x.split(' ')[-1] in end_words else x)
population_df.set_index(['State', 'County'], inplace = True)
convert(population_df)
population_df.drop(['Region', '2020_', '2021', '2020'], axis = 1, inplace = True)
population_df
# Out:
#           2022
# 1001    59,759
# 1003   246,435
# 1005    24,706
# 1007    22,005
# 1009    59,512
# ...        ...
# 56037   41,345
# 56039   23,287
# 56041   20,712
# 56043    7,719
# 56045    6,860
#
# [3109 rows x 1 columns]

# %%
idxs = [idx for idx in population_df.index if idx in df_all.index]
population_df = population_df.loc[idxs, :]
df_all = pd.concat([df_all, population_df], axis = 1)
df_all
# Out:
#       Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 1001             73                                   1.0   12.0    NaN
# 1003            127                                   1.0    5.0    NaN
# 1007              0                                   0.0    0.0    NaN
# 1009            394                                   1.0   17.0    NaN
# 1015             23                                   0.0    7.0    NaN
# ...             ...                                   ...    ...    ...
# 56035             3                                   0.0    0.0    NaN
# 56037            25                                   0.0    7.0    NaN
# 56041             4                                   0.0    0.0    NaN
# 56043             0                                   0.0    0.0    NaN
# 56045             1                                   0.0    0.0    NaN
#
#       Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 1001        8                 52            429      146           233
# 1003       23                 98            613      229           342
# 1007        0                  0             37       20            14
# 1009        9                367            867      261           501
# 1015        5                 11            319      137           181
# ...       ...                ...            ...      ...           ...
# 56035       1                  2             79        5            69
# 56037       0                 18            124       33            69
# 56041       0                  4             60        5            50
# 56043       0                  0             14        4             7
# 56045       0                  1              3        0             3
#
#       Motor vehicle theft  ...  Housing_Units  Tier_1  Tier_2  Tier_3  Tier_4  \
# 1001                   50  ...        22820.0     4.0     4.0     3.0     3.0
# 1003                   42  ...       106739.0     3.0     3.0     3.0     2.0
# 1007                    3  ...         9048.0     2.0     2.0     2.0     1.0
# 1009                  105  ...        24020.0     3.0     3.0     2.0     1.0
# 1015                    1  ...        53359.0     3.0     3.0     3.0     2.0
# ...                   ...  ...            ...     ...     ...     ...     ...
# 56035                   5  ...         5876.0     3.0     3.0     2.0     1.0
# 56037                  22  ...        19249.0     4.0     4.0     3.0     2.0
# 56041                   5  ...         8864.0     3.0     3.0     2.0     1.0
# 56043                   3  ...         3849.0     3.0     3.0     3.0     2.0
# 56045                   0  ...         3550.0     2.0     2.0     2.0     1.0
#
#        male_officer  female_officer  Republican  Democrat     2022
# 1001           35.0             3.0        0.52      0.35   59,759
# 1003          346.0            29.0        0.52      0.35  246,435
# 1007           24.0             0.0        0.52      0.35   22,005
# 1009           80.0             7.0        0.52      0.35   59,512
# 1015          173.0            13.0        0.52      0.35  115,788
# ...             ...             ...         ...       ...      ...
# 56035          40.0            11.0        0.57      0.25    8,763
# 56037          95.0            34.0        0.57      0.25   41,345
# 56041          46.0             3.0        0.57      0.25   20,712
# 56043          18.0             1.0        0.57      0.25    7,719
# 56045          13.0             2.0        0.57      0.25    6,860
#
# [2525 rows x 124 columns]

# %% [markdown]
# ## Race
#
# The formula for diversity index is
#
# $$D = 1 - \sum_{n \in S} \frac{n(n-1)}{N(N-1)}$$
#
# where $n$ is the number of individuals of a single species, $S$ is the set of all species, and $N$ is the number of individuals in the total population

# %%
path = paths['Raw Race Breakdown'][0]
race_df = pd.read_csv(path)
race_df.sample(3)
# Out:
#                  Location  Diversity-Index  \
# 2146  Sheridan County, WY         0.162154
# 286        Bee County, TX         0.553516
# 1136  Thurston County, WA         0.391913
#
#       Black or African American alone, percent, 2013  \
# 2146                                             1.2
# 286                                              8.5
# 1136                                             3.3
#
#       American Indian and Alaska Native alone, percent, 2013  \
# 2146                                                1.4
# 286                                                 0.8
# 1136                                                1.7
#
#       Asian alone, percent, 2013  \
# 2146                         0.8
# 286                          0.6
# 1136                         5.5
#
#       Native Hawaiian and Other Pacific Islander alone, percent,  \
# 2146                                                0.1
# 286                                                 0.1
# 1136                                                0.9
#
#       Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 2146                               1.4                                4.3
# 286                                1.1                               57.4
# 1136                               5.1                                8.1
#
#       White alone, not Hispanic or Latino, percent, 2013
# 2146                                               91.4
# 286                                                33.1
# 1136                                               77.1

# %%
idxs = [idx for idx in race_df.index if ',' in race_df.loc[idx, 'Location']]
idxs_ = [idx for idx in race_df.index if ',' not in race_df.loc[idx, 'Location']]
race_df.loc[idxs, 'State'] = race_df.loc[idxs, 'Location'].apply(lambda x: code_to_name[x.split(' ')[-1]])
race_df.loc[idxs_, 'State'] = race_df.loc[idxs_, 'Location']
race_df.loc[idxs, 'County'] = race_df.loc[idxs, 'Location'].apply(lambda x: x.split(',')[0])
race_df.loc[idxs_, 'County'] = race_df.loc[idxs_, 'Location']
race_df['County'] = race_df['County'].apply(lambda x: ' '.join(x.split(' ')[0:-1]) if x.split(' ')[-1] in end_words else x)
race_df.set_index(['State', 'County'], inplace = True)
convert(race_df)
race_df.drop('Location', axis = 1, inplace = True)
race_df
# Out:
#        Diversity-Index  Black or African American alone, percent, 2013  \
# 2016          0.769346                                             7.4
# 36081         0.742224                                            20.9
# 15009         0.740757                                             0.8
# 6001          0.740399                                            12.4
# 2013          0.738867                                             7.7
# ...                ...                                             ...
# 29151         0.037540                                             0.3
# 54043         0.035585                                             0.2
# 21131         0.035581                                             0.4
# 31009         0.023784                                             0.2
# 31103         0.021816                                             0.0
#
#        American Indian and Alaska Native alone, percent, 2013  \
# 2016                                                13.8
# 36081                                                1.3
# 15009                                                0.6
# 6001                                                 1.2
# 2013                                                21.8
# ...                                                  ...
# 29151                                                0.2
# 54043                                                0.1
# 21131                                                0.1
# 31009                                                0.0
# 31103                                                0.1
#
#        Asian alone, percent, 2013  \
# 2016                         31.1
# 36081                        25.2
# 15009                        28.8
# 6001                         28.2
# 2013                         41.4
# ...                           ...
# 29151                         0.1
# 54043                         0.1
# 21131                         0.2
# 31009                         0.0
# 31103                         0.1
#
#        Native Hawaiian and Other Pacific Islander alone, percent,  \
# 2016                                                 2.3
# 36081                                                0.2
# 15009                                               10.6
# 6001                                                 1.0
# 2013                                                 0.7
# ...                                                  ...
# 29151                                                0.0
# 54043                                                0.0
# 21131                                                0.0
# 31009                                                0.0
# 31103                                                0.0
#
#        Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 2016                                4.8                               14.6
# 36081                               2.7                               28.0
# 15009                              23.3                               10.7
# 6001                                5.2                               22.7
# 2013                                3.7                               13.5
# ...                                 ...                                ...
# 29151                               0.7                                0.6
# 54043                               0.7                                0.6
# 21131                               0.7                                0.5
# 31009                               0.8                                0.2
# 31103                               0.6                                0.5
#
#        White alone, not Hispanic or Latino, percent, 2013
# 2016                                                29.2
# 36081                                               26.7
# 15009                                               31.5
# 6001                                                33.2
# 2013                                                12.9
# ...                                                  ...
# 29151                                               98.1
# 54043                                               98.2
# 21131                                               98.2
# 31009                                               98.8
# 31103                                               98.9
#
# [3173 rows x 8 columns]

# %%
vis = {idx : True for idx in race_df.index}
discard = []
for idx in race_df.index:
    if vis[idx] == False:
        discard.append(idx)
    vis[idx] = False
discard = np.unique(discard)
race_df.drop(discard, inplace = True, axis = 0)

# %%
idxs = [idx for idx in race_df.index if idx in df_all.index]
race_df = race_df.loc[idxs, :]
df_all = pd.concat([df_all, race_df], axis = 1)
df_all
# Out:
#       Violent crime  Murder and nonnegligent manslaughter  Rape1  Rape2  \
# 1001             73                                   1.0   12.0    NaN
# 1003            127                                   1.0    5.0    NaN
# 1007              0                                   0.0    0.0    NaN
# 1009            394                                   1.0   17.0    NaN
# 1015             23                                   0.0    7.0    NaN
# ...             ...                                   ...    ...    ...
# 56035             3                                   0.0    0.0    NaN
# 56037            25                                   0.0    7.0    NaN
# 56041             4                                   0.0    0.0    NaN
# 56043             0                                   0.0    0.0    NaN
# 56045             1                                   0.0    0.0    NaN
#
#       Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 1001        8                 52            429      146           233
# 1003       23                 98            613      229           342
# 1007        0                  0             37       20            14
# 1009        9                367            867      261           501
# 1015        5                 11            319      137           181
# ...       ...                ...            ...      ...           ...
# 56035       1                  2             79        5            69
# 56037       0                 18            124       33            69
# 56041       0                  4             60        5            50
# 56043       0                  0             14        4             7
# 56045       0                  1              3        0             3
#
#       Motor vehicle theft  ...  Democrat     2022  Diversity-Index  \
# 1001                   50  ...      0.35   59,759         0.388898
# 1003                   42  ...      0.35  246,435         0.297942
# 1007                    3  ...      0.35   22,005         0.394100
# 1009                  105  ...      0.35   59,512         0.221056
# 1015                    1  ...      0.35  115,788         0.420387
# ...                   ...  ...       ...      ...              ...
# 56035                   5  ...      0.25    8,763         0.218882
# 56037                  22  ...      0.25   41,345         0.340296
# 56041                   5  ...      0.25   20,712         0.225552
# 56043                   3  ...      0.25    7,719         0.296868
# 56045                   0  ...      0.25    6,860         0.147697
#
#        Black or African American alone, percent, 2013  \
# 1001                                             18.4
# 1003                                              9.5
# 1007                                             22.1
# 1009                                              1.8
# 1015                                             20.9
# ...                                               ...
# 56035                                             1.4
# 56037                                             1.7
# 56041                                             0.8
# 56043                                             0.8
# 56045                                             0.6
#
#        American Indian and Alaska Native alone, percent, 2013  \
# 1001                                                 0.5
# 1003                                                 0.7
# 1007                                                 0.4
# 1009                                                 0.6
# 1015                                                 0.5
# ...                                                  ...
# 56035                                                1.1
# 56037                                                1.2
# 56041                                                1.3
# 56043                                                1.7
# 56045                                                1.7
#
#        Asian alone, percent, 2013  \
# 1001                          1.1
# 1003                          0.9
# 1007                          0.2
# 1009                          0.3
# 1015                          0.8
# ...                           ...
# 56035                         1.1
# 56037                         0.9
# 56041                         0.4
# 56043                         0.7
# 56045                         0.3
#
#        Native Hawaiian and Other Pacific Islander alone, percent,  \
# 1001                                                 0.1
# 1003                                                 0.1
# 1007                                                 0.1
# 1009                                                 0.1
# 1015                                                 0.1
# ...                                                  ...
# 56035                                                0.0
# 56037                                                0.2
# 56041                                                0.2
# 56043                                                0.1
# 56045                                                0.0
#
#        Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 1001                                1.7                                2.7
# 1003                                1.5                                4.6
# 1007                                0.9                                2.1
# 1009                                1.1                                8.7
# 1015                                1.6                                3.5
# ...                                 ...                                ...
# 56035                               1.4                                7.8
# 56037                               1.7                               15.9
# 56041                               1.7                                9.1
# 56043                               1.7                               14.2
# 56045                               2.1                                3.8
#
#        White alone, not Hispanic or Latino, percent, 2013
# 1001                                                75.9
# 1003                                                83.1
# 1007                                                74.6
# 1009                                                87.8
# 1015                                                73.1
# ...                                                  ...
# 56035                                               88.0
# 56037                                               79.6
# 56041                                               87.5
# 56043                                               82.6
# 56045                                               92.2
#
# [2525 rows x 132 columns]

# %% [markdown]
# ## Save new dataset

# %%
df_all.drop('FIPS', axis = 1, inplace = True)
df_all.to_csv('crime_re.csv')
